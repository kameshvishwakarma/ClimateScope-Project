# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\ClimateScope\Data\Processed\GlobalWeatherRepository.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\kames\AppData\Local\Temp\ipykernel_16600\2637621635.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df=pd.read_csv("C:\ClimateScope\Data\Processed\GlobalWeatherRepository.csv")

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %% [markdown]
# Dataset successfully loaded.
# Initial inspection shows weather measurements, air quality metrics,
# geographic coordinates, and astronomical information.

# %%
df.shape
# Out:
# (124526, 41)

# %%
df.dtypes #It returns the datatype of every column
# Out:
# country                             str
# location_name                       str
# latitude                        float64
# longitude                       float64
# timezone                            str
# last_updated_epoch                int64
# last_updated                        str
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                      str
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                      str
# pressure_mb                     float64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %% [markdown]
# To find the missing value we use
# # df.isnull()
#  If it found any missing values, it returns true otherwise false.

# %%
df.isnull()
# Out:
#         country  location_name  latitude  longitude  timezone  \
# 0         False          False     False      False     False
# 1         False          False     False      False     False
# 2         False          False     False      False     False
# 3         False          False     False      False     False
# 4         False          False     False      False     False
# ...         ...            ...       ...        ...       ...
# 124521    False          False     False      False     False
# 124522    False          False     False      False     False
# 124523    False          False     False      False     False
# 124524    False          False     False      False     False
# 124525    False          False     False      False     False
#
#         last_updated_epoch  last_updated  temperature_celsius  \
# 0                    False         False                False
# 1                    False         False                False
# ...

# %% [markdown]
# To count how many value are null/missing
# # df.isnull().sum()

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %% [markdown]
# Finding the duplicates value in data frame
# and count how many values are duplicated,
# there are no duplicated values present in data frame

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124526 entries, 0 to 124525
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       124526 non-null  str
#  1   location_name                 124526 non-null  str
#  2   latitude                      124526 non-null  float64
#  3   longitude                     124526 non-null  float64
#  4   timezone                      124526 non-null  str
#  5   last_updated_epoch            124526 non-null  int64
#  6   last_updated                  124526 non-null  str
#  7   temperature_celsius           124526 non-null  float64
#  8   temperature_fahrenheit        124526 non-null  float64
#  9   condition_text                124526 non-null  str
#  10  wind_mph                      124526 non-null  float64
#  11  wind_kph                      124526 non-null  float64
# ...

# %% [markdown]
# In the above output we found that last_updated column shows str datetime type
# So that convert into date type

# %%
df['last_updated'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['last_updated']=pd.to_datetime(df['last_updated'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124526 entries, 0 to 124525
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       124526 non-null  str
#  1   location_name                 124526 non-null  str
#  2   latitude                      124526 non-null  float64
#  3   longitude                     124526 non-null  float64
#  4   timezone                      124526 non-null  str
#  5   last_updated_epoch            124526 non-null  int64
#  6   last_updated                  124526 non-null  datetime64[us]
#  7   temperature_celsius           124526 non-null  float64
#  8   temperature_fahrenheit        124526 non-null  float64
#  9   condition_text                124526 non-null  str
#  10  wind_mph                      124526 non-null  float64
#  11  wind_kph                      124526 non-null  float64
# ...

# %% [markdown]
# Here I am checking how many unique countries are present.
# and how many times are repeated

# %%
df['country'].nunique()
# Out:
# 211

# %%
df['country'].value_counts()
# Out:
# country
# Bulgaria        1470
# Indonesia       1281
# Sudan           1278
# Thailand        1277
# Turkey          1277
#                 ...
# Südkorea           1
# Bélgica            1
# Turkménistan       1
# 火鸡                 1
# Jemen              1
# Name: count, Length: 211, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['temperature_celsius'],bins=35)
plt.title("Temperature Distribution")
plt.show()

# %%
df = df.drop(columns=[
    'temperature_fahrenheit',
    'feels_like_fahrenheit',
    'wind_mph',
    'gust_mph',
    'precip_in',
    'visibility_miles'
])

# %%
df.to_csv("C:\ClimateScope\Data\Processed\clean_data.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\kames\AppData\Local\Temp\ipykernel_16600\1670387007.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df.to_csv("C:\ClimateScope\Data\Processed\clean_data.csv", index=False)

# %%
df=pd.read_csv("C:/ClimateScope/Data/Processed/cleaned_data.csv")

# %%
df.shape
# Out:
# (124526, 35)

# %%
df_sample = df.sample(1000)   # take 1000 rows
df_sample.to_csv("C:\ClimateScope\Data\Processed\clean_data.csv", index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\kames\AppData\Local\Temp\ipykernel_16600\2849382224.py:2: SyntaxWarning: invalid escape sequence '\C'
#   df_sample.to_csv("C:\ClimateScope\Data\Processed\clean_data.csv", index=False)
